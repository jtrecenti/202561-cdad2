# %%
import juscraper as jus

# cria um objeto tjsp
tjsp = jus.scraper('tjsp')

# baixa dados da consulta de julgados de primeiro grau
dados_cjpg = tjsp.cjpg('golpe do pix', paginas=range(1,3))
dados_cjpg
# Out:
# Total de páginas: 2213
# Paginas a serem baixadas: [1, 2]
# ...
# Processando documentos: 100%|██████████| 2/2 [00:00<00:00, 20.63it/s]
#       cd_processo                id_processo  \
# 0   7G0006O9V0000  1008430-56.2024.8.26.0268
# 1   360015Z7A0000  1053443-55.2024.8.26.0114
# 2   EP0006NGL0000  1006200-34.2024.8.26.0529
# 3   GU00071910000  0004275-80.2024.8.26.0606
# 4   68001NYKQ0000  1010908-72.2024.8.26.0224
# 5   3000045JG0000  1000013-75.2025.8.26.0108
# 6   8E0007S990000  0002114-39.2024.8.26.0302
# 7   DC00027IV0000  1001099-66.2024.8.26.0480
# 8   11000HOHI0000  1008887-05.2024.8.26.0037
# 9   01001TNMP0000  1035486-89.2024.8.26.0001
# 10  01001U1WM0000  1046970-04.2024.8.26.0001
# 11  G0000THER0000  1016860-43.2024.8.26.0576
# 12  8W000F9PT0000  1016122-47.2024.8.26.0320
# 13  GU00072830000  0004616-09.2024.8.26.0606
# 14  2S001X3IY0000  1153977-49.2024.8.26.0100
# 15  11000HDGS0000  1001519-42.2024.8.26.0037
# 16  6W0008UHH0000  1009623-06.2023.8.26.0248
# ...

# %%
tjsp.cjpg()
# Out:
# <bound method TJSP_Scraper.cjpg of <juscraper.tjsp_scraper.TJSP_Scraper object at 0x000001D85B78D7C0>>
